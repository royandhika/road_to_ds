# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\Data Analytics\Project\my_finance_report\my_report.csv', sep = ";")

# %%
df.columns = df.columns.str.lower()
dft = pd.DataFrame(df['tanggal'])
dft.tail()
# Out:
#         tanggal
# 783  02/07/2022
# 784  02/07/2022
# 785  02/07/2022
# 786  06/07/2022
# 787  06/07/2022

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tanggal  788 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 6.3 KB

# %% [markdown]
# ## Mengubah dtype ke datetime64[ns]

# %%
# gunakan infer_datetime_format
pd.to_datetime(dft['tanggal'], infer_datetime_format=True)
# dft['tanggal'] = pd.to_datetime(dft['tanggal'], format='%d/%m/%Y')
# pd.to_datetime(dft['tanggal'], format = '%Y')
# gunakan format untuk menyesuaikan format scr manual
# Out:
# 0     2022-02-28
# 1     2022-02-28
# 2     2022-02-28
# 3     2022-02-28
# 4     2022-02-28
#          ...
# 783   2022-07-02
# 784   2022-07-02
# 785   2022-07-02
# 786   2022-07-06
# 787   2022-07-06
# Name: tanggal, Length: 788, dtype: datetime64[ns]

# %%
# convert otomatis, format tidak konsisten
dft['tanggal'].astype('datetime64[ns]')

# %% [markdown]
# ## Ekstrak format
# Ekstrak dari value yang **sudah** bertipe **datetime**, hasilnya berbentuk **object**

# %%
from IPython.display import Image
Image("dataset\ss.png")

# %%
dft['tanggal'].dt.day
# dt.year dt.month dt.time dt.date
# Out:
# 0      28
# 1      28
# 2      28
# 3      28
# 4      28
#        ..
# 783     2
# 784     2
# 785     2
# 786     6
# 787     6
# Name: tanggal, Length: 788, dtype: int64

# %%
dft['tanggal'].dt.strftime('%b')
# Out:
# 0      Feb
# 1      Feb
# 2      Feb
# 3      Feb
# 4      Feb
#       ...
# 783    Jul
# 784    Jul
# 785    Jul
# 786    Jul
# 787    Jul
# Name: tanggal, Length: 788, dtype: object

# %% [markdown]
# ## Convert to period
# Ubah ke datetype period

# %%
dft['tanggal'].dt.to_period('M')
# Out:
# 0      2022-02
# 1      2022-02
# 2      2022-02
# 3      2022-02
# 4      2022-02
#         ...
# 783    2022-07
# 784    2022-07
# 785    2022-07
# 786    2022-07
# 787    2022-07
# Name: tanggal, Length: 788, dtype: period[M]
