# %% [markdown]
# # Belajar Statistik #lanjutan

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('D:\Data Analytics\Project\data_science_learning\dataset\car_price.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# ## Descriptive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginesize   boreratio      stroke  compressionratio  horsepower  \
# count  205.000000  205.000000  205.000000        205.000000  205.000000
# mean   126.907317    3.329756    3.255415         10.142537  104.117073
# std     41.642693    0.270844    0.313597          3.972040   39.544167
# min     61.000000    2.540000    2.070000          7.000000   48.000000
# ...

# %%
df.describe(include='object')
# Out:
#         car_ID  symboling        CarName fueltype aspiration doornumber  \
# count      205        205            205      205        205        205
# unique     205          6            147        2          2          2
# top          1          0  toyota corona      gas        std       four
# freq         1         67              6      185        168        115
#
#        carbody drivewheel enginelocation enginetype cylindernumber fuelsystem
# count      205        205            205        205            205        205
# unique       5          3              2          7              7          8
# top      sedan        fwd          front        ohc           four       mpfi
# freq        96        120            202        148            159         94

# %% [markdown]
# ### Numerik

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df.corr(), xticklabels=dfcorr.columns, yticklabels=dfcorr.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (16,8))
plt.subplot(1,2,1)
sns.regplot(data = df, x = 'enginesize', y = 'price')
plt.title('Enginesize to Price', fontsize = 18)
plt.subplot(1,2,2)
sns.regplot(data = df, x = 'horsepower', y = 'price')
plt.ylim(0,)
plt.title('Horsepower to Price', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Horsepower to Price')

# %%
sns.pairplot(df, kind = 'reg')

# %% [markdown]
# ### Kategorik

# %%
plt.figure(figsize=(16,20))

plt.subplot(3,2,1)
sns.boxplot(data = df, x = 'carbody', y = 'price')

plt.subplot(3,2,2)
sns.boxplot(data = df, x = 'doornumber', y = 'price')

plt.subplot(3,2,3)
sns.boxplot(data = df, x = 'enginelocation', y = 'price')

plt.subplot(3,2,4)
sns.boxplot(data = df, x = 'drivewheel', y = 'price')

plt.subplot(3,2,5)
sns.boxplot(data = df, x = 'fueltype', y = 'price')

plt.subplot(3,2,6)
sns.boxplot(data = df, x = 'aspiration', y = 'price')
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='price'>

# %% [markdown]
# ## Correlation
# Pearson Correlation

# %%
pearson_coef, p_value = stats.pearsonr(df['citympg'], df['price'])
print(f'Correlation citympg dengan price')
print(f'Nilai Pearson coefficient adalah {pearson_coef} \ndan p-valuenya adalah {p_value}')
# Out:
# Correlation citympg dengan price
# Nilai Pearson coefficient adalah -0.6857513360270401
# dan p-valuenya adalah 7.978684249663295e-30

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print(f'Correlation horsepower dengan price')
print(f'Nilai Pearson coefficient adalah {pearson_coef} \ndan p-valuenya adalah {p_value}')
# Out:
# Correlation horsepower dengan price
# Nilai Pearson coefficient adalah 0.8081388225362219
# dan p-valuenya adalah 1.4834365732938807e-48

# %% [markdown]
# ## Chi-Square

# %%
pd.crosstab(df['fueltype'], df['aspiration'], normalize = True)
# Out:
# aspiration       std     turbo
# fueltype
# diesel      0.034146  0.063415
# gas         0.785366  0.117073

# %%
sns.heatmap(pd.crosstab(df['fueltype'], df['aspiration'], normalize = True))
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='fueltype'>

# %%
stats.chi2_contingency(pd.crosstab(df['fueltype'], df['aspiration']))
# Out:
# (29.605759385109046,
#  5.2947382636786724e-08,
#  1,
#  array([[ 16.3902439,   3.6097561],
#         [151.6097561,  33.3902439]]))
